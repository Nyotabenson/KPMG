# %%
import pandas as pd

# %%
# files
dataset = "KPMG_VI_New_raw_data_update_final.xlsx"
sheet1 = "Transactions"
sheet2 = "NewCustomerList"
sheet3 = "CustomerDemographic"
sheet4 = "CustomerAddress"

# %% [markdown]
#  <h1 style="font-size:8rem;color:red;"> Transactions</h1>

# %%
Transactions = pd.read_excel(dataset, sheet_name=sheet1)

# %%
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.shape
# Out:
# (20000, 13)

# %%
Transactions.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
Transactions.online_order.value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
# fill in the missing data

Transactions["online_order"].fillna(0, inplace=True)

missing_list = ["brand", "product_line", "product_class", "product_size"]
for i in missing_list:
    Transactions[i].fillna("missing", inplace=True)
    
Transactions["standard_cost"].fillna(Transactions["standard_cost"].mean(), inplace=True)

Transactions["product_first_sold_date"].fillna(Transactions["product_first_sold_date"].mean(), inplace=True)

# %%
Transactions.isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
Transactions.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  20000.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.491450   1107.829449
# std       5773.647028     30.75359   1011.951046      0.499939    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      0.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   20000.000000             20000.000000
# mean      556.046951             38199.776549
# std       403.951280              2861.004990
# min         7.210000             33259.000000
# ...

# %%
Transactions.sort_values("transaction_date").head()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 516               517          77          311       2017-01-01           1.0
# 5876             5877          67          138       2017-01-01           0.0
# 3459             3460          64          234       2017-01-01           1.0
# 12484           12485          85         2805       2017-01-01           1.0
# 19130           19131           0         1707       2017-01-01           0.0
#
#       order_status           brand product_line product_class product_size  \
# 516       Approved        WeareA2B     Standard        medium       medium
# 5876      Approved  Norco Bicycles         Road        medium       medium
# 3459      Approved  Giant Bicycles     Standard          high        small
# 12484     Approved        WeareA2B     Standard        medium       medium
# 19130     Approved   Trek Bicycles         Road        medium       medium
#
# ...

# %%
Transactions['transaction_date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
Transactions['transaction_date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
unique = ["product_line","product_class","product_size"]
for i in unique:
    print(Transactions[i].unique())
# Out:
# ['Standard' 'Road' 'Mountain' 'Touring' 'missing']
# ['medium' 'low' 'high' 'missing']
# ['medium' 'large' 'small' 'missing']

# %%
Transactions.duplicated().sum()
# Out:
# 0

# %%
# Saving new dataframe

Transactions.to_csv("Transactions.csv", index=False)

# %% [markdown]
#  <h1 style="font-size:5rem;color:red;"> NewCustomerList</h1>

# %%
NewCustomerList = pd.read_excel(dataset, sheet_name=sheet2).drop(columns=
                            ["Unnamed: 16","Unnamed: 17","Unnamed: 18","Unnamed: 19","Unnamed: 20"], axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17096\3887268291.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   NewCustomerList = pd.read_excel(dataset, sheet_name=sheet2).drop(columns=

# %%
pd.set_option('display.max_columns', None)
NewCustomerList.head(30)
# Out:
#    first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0     Chickie       Brister    Male                                   86
# 1       Morly        Genery    Male                                   69
# 2     Ardelis     Forrester  Female                                   10
# 3      Lucine         Stutt  Female                                   64
# 4     Melinda        Hadlee  Female                                   34
# 5       Druci       Brandli  Female                                   39
# 6    Rutledge         Hallt    Male                                   23
# 7      Nancie          Vian  Female                                   74
# 8        Duff     Karlowicz    Male                                   50
# 9     Barthel        Docket    Male                                   72
# 10   Rockwell        Matson    Male                                   94
# 11    Wheeler       Winward    Male                                   48
# ...

# %%
NewCustomerList.shape
# Out:
# (1000, 18)

# %%
NewCustomerList.isna().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
missing = ["last_name", "job_title", "job_industry_category"]
for i in missing:
    NewCustomerList[i].fillna("missing", inplace=True)
NewCustomerList.dropna(inplace=True)

# %%
NewCustomerList.isna().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Rank                                   0
# Value                                  0
# dtype: int64

# %%
NewCustomerList.describe()
# Out:
#        past_3_years_bike_related_purchases      tenure    postcode  \
# count                           983.000000  983.000000   983.00000
# mean                             49.824008   11.459817  3017.74059
# std                              27.786108    5.006123   849.38176
# min                               0.000000    1.000000  2000.00000
# 25%                              27.000000    8.000000  2209.00000
# 50%                              51.000000   11.000000  2795.00000
# 75%                              72.000000   15.000000  3850.50000
# max                              99.000000   22.000000  4879.00000
#
#        property_valuation         Rank       Value
# count          983.000000   983.000000  983.000000
# mean             7.406918   497.745677    0.882926
# std              2.758293   289.186799    0.294166
# min              1.000000     1.000000    0.340000
# 25%              6.000000   248.500000    0.650781
# 50%              8.000000   500.000000    0.860000
# ...

# %%
NewCustomerList.sort_values("DOB").head()
# Out:
#     first_name   last_name  gender  past_3_years_bike_related_purchases  \
# 797    Anthony     Morison    Male                                    7
# 885  Zachariah  Meininking    Male                                   40
# 769     Andrea      Pendle  Female                                   86
# 585    Letizia       Poore  Female                                   27
# 265     Alleen       Eaken  Female                                   56
#
#            DOB         job_title job_industry_category     wealth_segment  \
# 797 1938-06-08   General Manager                Health      Mass Customer
# 885 1938-06-09   Cost Accountant    Financial Services  Affluent Customer
# 769 1938-08-05           missing               missing     High Net Worth
# 585 1938-08-30  Web Developer II         Manufacturing  Affluent Customer
# 265 1938-08-31           missing               missing      Mass Customer
#
#     deceased_indicator owns_car  tenure                  address  postcode  \
# ...

# %%
unique=["gender", "wealth_segment", "deceased_indicator", "owns_car"]
for i in unique:
    print(NewCustomerList[i].unique())
# Out:
# ['Male' 'Female']
# ['Mass Customer' 'Affluent Customer' 'High Net Worth']
# ['N']
# ['Yes' 'No']

# %%
NewCustomerList.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  <h1 style="font-size:5rem;color:red;"> CustomerDemographic</h1>

# %%
CustomerDemographic = pd.read_excel(dataset, sheet_name=sheet3)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17096\2638969078.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   CustomerDemographic = pd.read_excel(dataset, sheet_name=sheet3)

# %%
CustomerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
CustomerDemographic.shape
# Out:
# (4000, 13)

# %%
CustomerDemographic.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
CustomerDemographic=CustomerDemographic.drop(columns=["default"], axis=1)

missing = ["last_name", "job_title", "job_industry_category"]
for i in missing:
    CustomerDemographic[i].fillna("missing", inplace=True)
    
CustomerDemographic['tenure'].fillna(CustomerDemographic['tenure'].mean(), inplace=True)

CustomerDemographic.dropna(inplace=True)

# %%
# Dropping the invalid DOB 

CustomerDemographic = CustomerDemographic.drop(index = 33, axis=0)

# %%
CustomerDemographic.isna().sum()
# Out:
# customer_id                            0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# dtype: int64

# %%
CustomerDemographic.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  3912.000000                          3912.000000  3912.000000
# mean   1999.828221                            49.039366    10.654652
# std    1154.903377                            28.768226     5.658898
# min       1.000000                             0.000000     1.000000
# 25%    1002.750000                            24.000000     6.000000
# 50%    2000.000000                            48.000000    11.000000
# 75%    2997.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
CustomerDemographic.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure'],
#       dtype='object')

# %%
CustomerDemographic.sort_values("DOB").head()
# Out:
#       customer_id first_name last_name  gender  \
# 719           720     Darrel     Canet    Male
# 1091         1092     Katlin   Creddon  Female
# 3409         3410    Merrili   Brittin  Female
# 2412         2413      Abbey    Murrow    Male
# 657           658       Donn   Bonnell    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 719                                    67 1931-10-23
# 1091                                   56 1935-08-22
# 3409                                   93 1940-09-22
# 2412                                   27 1943-08-11
# 657                                    38 1944-01-24
#
#                      job_title job_industry_category     wealth_segment  \
# 719         Recruiting Manager                Retail  Affluent Customer
# 1091        VP Quality Control                Retail      Mass Customer
# 3409                   missing              Property      Mass Customer
# ...

# %%
# save

CustomerDemographic.to_csv("CustomerDemographic.csv")

# %% [markdown]
# <h1 style="font-size:5rem;color:red;"> CustomerAddress</h1>

# %%
CustomerAddress = pd.read_excel(dataset, sheet_name=sheet4)

# %%
CustomerAddress.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
CustomerAddress.shape
# Out:
# (3999, 6)

# %%
CustomerAddress.isna().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
# Save

CustomerAddress.to_csv("CustomerAddress.csv")
